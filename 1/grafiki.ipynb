# %%
import numpy as np
import scipy.stats as sps
import matplotlib.pyplot as plt
import math
import time
import tqdm

# %% [markdown]
# ### Задача №1

# %%
grid = np.arange(6)+1
result = [26.7878, 13.1209, 8.88511, 13.3661, 13.0363, 14.0827]

plt.plot(grid, result, color='blue')
plt.show()

# %% [markdown]
# ### Задача №2

# %%
grid = np.arange(6)+1
result = [2.30928, 1.1814, 0.852856, 0.793062, 0.764625, 0.745706]

plt.plot(grid, result, color='blue')
plt.show()
